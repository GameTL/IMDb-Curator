# %% [markdown]
# # Setup

# %%
import pandas as pd
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.feature_extraction.text import TfidfVectorizer
import os

# if ' processing_df_.csv' in os.listdir('../data'):
#     print("Partial dataset found!")
#     # use partial or full dataset
#     df_file_name = 'filtered_df_synopsis.csv'
# else:
# use draft dataset
df_file_name = 'filtered_df.csv'

print(f"Using {df_file_name} as dataset.")
    
try:
    df = pd.read_csv(f'../data/{df_file_name}', low_memory=False)
except FileNotFoundError as e:
    print("File not found. Download the IMDB_Dataset.")
    raise e

pd.options.display.max_columns = None
pd.options.display.max_rows = 100

print(df.columns)
print(df.isnull().sum())
# Out:
# Using filtered_df.csv as dataset.
# Index(['Best Picture', 'Certificate (GB)', 'Certificate (US)', 'Genres (1st)',
#        'Genres (2nd)', 'Genres (3rd)', 'Genres (full list)',
#        'Image Url (Title)', 'IMDB Url (title)', 'Plot', 'Plot (medium)',
#        'Production Companies (1st)', 'Production Companies (2nd)',
#        'Production Companies (3rd)', 'Production Companies (List)', 'Tagline',
#        'Title', 'Title Id', 'What did they do ?', 'Year of Release',
#        'IMDB Rating', 'Number Of Votes', 'Runtime (Minutes)', 'Lead Actors'],
#       dtype='object')
# Best Picture                   17707
# Certificate (GB)                3407
# Certificate (US)                1466
# Genres (1st)                       1
# Genres (2nd)                    2842
# Genres (3rd)                    8254
# Genres (full list)                 1
# Image Url (Title)                  1
# IMDB Url (title)                   0
# Plot                               2
# Plot (medium)                   2943
# Production Companies (1st)       283
# Production Companies (2nd)      3777
# Production Companies (3rd)      8121
# Production Companies (List)      283
# Tagline                         4016
# Title                              0
# Title Id                           0
# What did they do ?                 0
# Year of Release                    0
# IMDB Rating                        0
# Number Of Votes                    0
# Runtime (Minutes)                  0
# Lead Actors                        0
# dtype: int64

# %% [markdown]
# # Data

# %%
processing_df = df[df['Plot'].notna() & df['Genres (full list)'].notna() & df['Production Companies (1st)'].notna()]

processing_df['Best Picture'] = processing_df['Best Picture'].fillna('None')
processing_df['Certificate (GB)'] = processing_df['Certificate (GB)'].fillna('None')
processing_df['Certificate (US)'] = processing_df['Certificate (US)'].fillna('None')

processing_df.drop(['Genres (1st)',
       'Genres (2nd)', 'Genres (3rd)',
       'IMDB Url (title)', 'Plot (medium)',
       'Production Companies (List)', 'Production Companies (2nd)',
       'Production Companies (3rd)', 'Tagline', 'What did they do ?',
        'Number Of Votes'], axis=1, inplace=True)
print(processing_df.isnull().sum())
processing_df
# Out:
# Best Picture                  0
# Certificate (GB)              0
# Certificate (US)              0
# Genres (full list)            0
# Image Url (Title)             0
# Plot                          0
# Production Companies (1st)    0
# Title                         0
# Title Id                      0
# Year of Release               0
# IMDB Rating                   0
# Runtime (Minutes)             0
# Lead Actors                   0
# dtype: int64
# /var/folders/kl/36jj5f7x65x2wm9_48xpty780000gn/T/ipykernel_19385/1236493600.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   processing_df['Best Picture'] = processing_df['Best Picture'].fillna('None')
# /var/folders/kl/36jj5f7x65x2wm9_48xpty780000gn/T/ipykernel_19385/1236493600.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   processing_df['Certificate (GB)'] = processing_df['Certificate (GB)'].fillna('None')
# /var/folders/kl/36jj5f7x65x2wm9_48xpty780000gn/T/ipykernel_19385/1236493600.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   processing_df['Certificate (US)'] = processing_df['Certificate (US)'].fillna('None')
# /var/folders/kl/36jj5f7x65x2wm9_48xpty780000gn/T/ipykernel_19385/1236493600.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   processing_df.drop(['Genres (1st)',
#       Best Picture Certificate (GB) Certificate (US)  \
# 0             None               PG               PG
# 1             None               15                R
# 2             None               PG            PG-13
# 3             None             None            PG-13
# 4             None               15                R
# ...            ...              ...              ...
# 17947         None             None        Not Rated
# 17948         None               18                R
# 17950         None             None             None
# 17951         None               15        Not Rated
# 17952         None               12            TV-PG
#
#                             Genres (full list)  \
# 0      Adventure,Comedy,Mystery,Romance,Sci-Fi
# 1                                       Comedy
# 2                                Drama,Romance
# 3                                        Drama
# 4                Action,Horror,Sci-Fi,Thriller
# ...                                        ...
# 17947                        Documentary,Crime
# 17948                        Documentary,Crime
# 17950                      Documentary,History
# 17951                 Documentary,History,News
# 17952                      Documentary,History
#
#                                        Image Url (Title)  \
# 0      https://m.media-amazon.com/images/M/MV5BZjI0YT...
# 1      https://m.media-amazon.com/images/M/MV5BNGM1ND...
# 2      https://m.media-amazon.com/images/M/MV5BNzI4OT...
# 3      https://m.media-amazon.com/images/M/MV5BMjAzMT...
# 4      https://m.media-amazon.com/images/M/MV5BNDlmOT...
# ...                                                  ...
# 17947  https://m.media-amazon.com/images/M/MV5BMTkyNj...
# 17948  https://m.media-amazon.com/images/M/MV5BNDIyMj...
# 17950  https://m.media-amazon.com/images/M/MV5BMjA1ND...
# 17951  https://m.media-amazon.com/images/M/MV5BMTg2NT...
# 17952  https://m.media-amazon.com/images/M/MV5BMmVkN2...
#
#                                                     Plot  \
# 0      The seniors return to Earth to visit their rel...
# 1      A sendup of all the teen movies that have accu...
# 2      A chef with a mysterious past spends the day w...
# 3      Two brothers and their surfing buddies face ne...
# 4      Sean Barker, unwilling host to an alien bio-ar...
# ...                                                  ...
# 17947  An investigative documentary about the epidemi...
# 17948  A documentary of the decline of America. It fe...
# 17950  Featuring never-before-seen footage, this docu...
# 17951  The story of two coalitions -- ACT UP and TAG ...
# 17952  Based on newly declassified files, Sam Pollard...
#
#       Production Companies (1st)  \
# 0       Zanuck/Brown Productions
# 1              Columbia Pictures
# 2                 Metanoia Films
# 3              Capstone Pictures
# 4                 Biomorphs Inc.
# ...                          ...
# 17947      Chain Camera Pictures
# 17948     Filmlink International
# 17950       Firelight Media Inc.
# 17951        Public Square Films
# 17952       Field of Vision (II)
#
#                                                  Title    Title Id  \
# 0                                   Cocoon: The Return   tt0094890
# 1                               Not Another Teen Movie   tt0277371
# 2                                                Bella   tt0482463
# 3                                           Local Boys   tt0293357
# 4                                    Guyver: Dark Hero   tt0109965
# ...                                                ...         ...
# 17947                                The Invisible War   tt2120152
# 17948                           The Killing of America   tt0157894
# 17950  Jonestown: The Life and Death of Peoples Temple   tt0762111
# 17951                          How to Survive a Plague   tt2124803
# 17952                                          MLK/FBI  tt12801356
#
#        Year of Release  IMDB Rating  Runtime (Minutes)  \
# 0                 1988          5.4              116.0
# 1                 2001          5.7               89.0
# 2                 2006          7.1               91.0
# 3                 2002          6.6              102.0
# 4                 1994          5.8              118.0
# ...                ...          ...                ...
# 17947             2012          7.6               93.0
# 17948             1981          7.6               90.0
# 17950             2006          7.8               86.0
# 17951             2012          7.6              110.0
# 17952             2020          7.0              104.0
#
#                                              Lead Actors
# 0      ['Priscilla Ashley Behne', 'Bill Wohrman', 'Ba...
# 1      ['Lukas Behnken', 'Cody McMains', 'Deon Richmo...
# 2      ['Lukas Behnken', 'Dominic Colón', 'Hudson Coo...
# 3      ['Lukas Behnken', 'Travis Aaron Wade', 'Dick D...
# 4      ["'Evil' Ted Smith", 'Billi Lee', 'Brian Simps...
# ...                                                  ...
# 17947                                     ['Kirby Dick']
# 17948                                  ['Sheldon Renan']
# 17950                                 ['Stanley Nelson']
# 17951                                   ['David France']
# 17952                                    ['Sam Pollard']
#
# [17667 rows x 13 columns]

# %% [markdown]
# ## Listifying

# %%
import re

# Function to process company names
def alphanumericify(text):
    # Remove non-alphanumeric characters and strip whitespace
    return   re.sub(r'[^A-Za-z0-9 ]+', '', text)


# Split the 'Genres (full list)' column on commas
processing_df['genres'] = processing_df['Genres (full list)'].str.split(',') #.apply(lambda x: [alphanumericify(item) for item in x])
# processing_df['genres'] = processing_df['Genres (full list)']
# Display the DataFrame to verify the new 'genres' column
print(processing_df[['Title', 'genres']].head())

processing_df
# Out:
#                     Title                                         genres
# 0      Cocoon: The Return  [Adventure, Comedy, Mystery, Romance, Sci-Fi]
# 1  Not Another Teen Movie                                       [Comedy]
# 2                   Bella                               [Drama, Romance]
# 3              Local Boys                                        [Drama]
# 4       Guyver: Dark Hero             [Action, Horror, Sci-Fi, Thriller]
# /var/folders/kl/36jj5f7x65x2wm9_48xpty780000gn/T/ipykernel_19385/320209667.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   processing_df['genres'] = processing_df['Genres (full list)'].str.split(',') #.apply(lambda x: [alphanumericify(item) for item in x])
#       Best Picture Certificate (GB) Certificate (US)  \
# 0             None               PG               PG
# 1             None               15                R
# 2             None               PG            PG-13
# 3             None             None            PG-13
# 4             None               15                R
# ...            ...              ...              ...
# 17947         None             None        Not Rated
# 17948         None               18                R
# 17950         None             None             None
# 17951         None               15        Not Rated
# 17952         None               12            TV-PG
#
#                             Genres (full list)  \
# 0      Adventure,Comedy,Mystery,Romance,Sci-Fi
# 1                                       Comedy
# 2                                Drama,Romance
# 3                                        Drama
# 4                Action,Horror,Sci-Fi,Thriller
# ...                                        ...
# 17947                        Documentary,Crime
# 17948                        Documentary,Crime
# 17950                      Documentary,History
# 17951                 Documentary,History,News
# 17952                      Documentary,History
#
#                                        Image Url (Title)  \
# 0      https://m.media-amazon.com/images/M/MV5BZjI0YT...
# 1      https://m.media-amazon.com/images/M/MV5BNGM1ND...
# 2      https://m.media-amazon.com/images/M/MV5BNzI4OT...
# 3      https://m.media-amazon.com/images/M/MV5BMjAzMT...
# 4      https://m.media-amazon.com/images/M/MV5BNDlmOT...
# ...                                                  ...
# 17947  https://m.media-amazon.com/images/M/MV5BMTkyNj...
# 17948  https://m.media-amazon.com/images/M/MV5BNDIyMj...
# 17950  https://m.media-amazon.com/images/M/MV5BMjA1ND...
# 17951  https://m.media-amazon.com/images/M/MV5BMTg2NT...
# 17952  https://m.media-amazon.com/images/M/MV5BMmVkN2...
#
#                                                     Plot  \
# 0      The seniors return to Earth to visit their rel...
# 1      A sendup of all the teen movies that have accu...
# 2      A chef with a mysterious past spends the day w...
# 3      Two brothers and their surfing buddies face ne...
# 4      Sean Barker, unwilling host to an alien bio-ar...
# ...                                                  ...
# 17947  An investigative documentary about the epidemi...
# 17948  A documentary of the decline of America. It fe...
# 17950  Featuring never-before-seen footage, this docu...
# 17951  The story of two coalitions -- ACT UP and TAG ...
# 17952  Based on newly declassified files, Sam Pollard...
#
#       Production Companies (1st)  \
# 0       Zanuck/Brown Productions
# 1              Columbia Pictures
# 2                 Metanoia Films
# 3              Capstone Pictures
# 4                 Biomorphs Inc.
# ...                          ...
# 17947      Chain Camera Pictures
# 17948     Filmlink International
# 17950       Firelight Media Inc.
# 17951        Public Square Films
# 17952       Field of Vision (II)
#
#                                                  Title    Title Id  \
# 0                                   Cocoon: The Return   tt0094890
# 1                               Not Another Teen Movie   tt0277371
# 2                                                Bella   tt0482463
# 3                                           Local Boys   tt0293357
# 4                                    Guyver: Dark Hero   tt0109965
# ...                                                ...         ...
# 17947                                The Invisible War   tt2120152
# 17948                           The Killing of America   tt0157894
# 17950  Jonestown: The Life and Death of Peoples Temple   tt0762111
# 17951                          How to Survive a Plague   tt2124803
# 17952                                          MLK/FBI  tt12801356
#
#        Year of Release  IMDB Rating  Runtime (Minutes)  \
# 0                 1988          5.4              116.0
# 1                 2001          5.7               89.0
# 2                 2006          7.1               91.0
# 3                 2002          6.6              102.0
# 4                 1994          5.8              118.0
# ...                ...          ...                ...
# 17947             2012          7.6               93.0
# 17948             1981          7.6               90.0
# 17950             2006          7.8               86.0
# 17951             2012          7.6              110.0
# 17952             2020          7.0              104.0
#
#                                              Lead Actors  \
# 0      ['Priscilla Ashley Behne', 'Bill Wohrman', 'Ba...
# 1      ['Lukas Behnken', 'Cody McMains', 'Deon Richmo...
# 2      ['Lukas Behnken', 'Dominic Colón', 'Hudson Coo...
# 3      ['Lukas Behnken', 'Travis Aaron Wade', 'Dick D...
# 4      ["'Evil' Ted Smith", 'Billi Lee', 'Brian Simps...
# ...                                                  ...
# 17947                                     ['Kirby Dick']
# 17948                                  ['Sheldon Renan']
# 17950                                 ['Stanley Nelson']
# 17951                                   ['David France']
# 17952                                    ['Sam Pollard']
#
#                                               genres
# 0      [Adventure, Comedy, Mystery, Romance, Sci-Fi]
# 1                                           [Comedy]
# 2                                   [Drama, Romance]
# 3                                            [Drama]
# 4                 [Action, Horror, Sci-Fi, Thriller]
# ...                                              ...
# 17947                           [Documentary, Crime]
# 17948                           [Documentary, Crime]
# 17950                         [Documentary, History]
# 17951                   [Documentary, History, News]
# 17952                         [Documentary, History]
#
# [17667 rows x 14 columns]

# %% [markdown]
# ## Adding plot_keywords
#
# Adding plot_keywords to each movie

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
import pandas as pd

# Assuming 'processing_df' is your DataFrame and 'Plot' is the column with plot descriptions
tfidf_vectorizer = TfidfVectorizer(max_features=100, stop_words='english')  # Adjust max_features as needed
tfidf_matrix = tfidf_vectorizer.fit_transform( processing_df['Plot'])

# Get the feature names which represent the keywords
feature_names = tfidf_vectorizer.get_feature_names_out()

# Function to get keywords for each movie
def get_keywords(row, features):
    # Sort indices of nonzero elements
    sorted_indices = row.nonzero()[1]
    # Get corresponding feature names (keywords)
    keywords = [features[i] for i in sorted_indices]
    return keywords

# Extract keywords for each movie
processing_df['plot_keywords'] = [get_keywords(row, feature_names) for row in tfidf_matrix]

# Sort movies by the length of the keyword list
sorted_df = processing_df.sort_values(by='plot_keywords', key=lambda x: x.str.len(), ascending=False)

# Displaying the sorted DataFrame
print(sorted_df[['Title', 'plot_keywords']])
# Out:
#                  Title                                      plot_keywords
# 12264    Soul Assassin  [future, death, true, dead, crime, father, mot...
# 1936            Hoovey  [work, true, school, living, story, boy, fathe...
# 10604         Betrayal  [house, look, dead, gets, small, drug, mother,...
# 11431           Rancid  [future, tries, work, school, best, murder, ge...
# 17183   Real Gangsters  [future, work, living, story, crime, finds, ci...
# ...                ...                                                ...
# 9881        Studio 666                                                 []
# 3971   Debt Collectors                                                 []
# 3975          Galaxina                                                 []
# 3976         Coneheads                                                 []
# 11850         Land Ho!                                                 []
#
# [17667 rows x 2 columns]
# /var/folders/kl/36jj5f7x65x2wm9_48xpty780000gn/T/ipykernel_19385/2452684901.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   processing_df['plot_keywords'] = [get_keywords(row, feature_names) for row in tfidf_matrix]

# %% [markdown]
# ## Count most common keyword

# %%
from collections import Counter

# Flatten the list of keywords from all movies into a single list
all_keywords = sum(processing_df['plot_keywords'].tolist(), [])

# Calculate the frequency of each keyword
keyword_freq = Counter(all_keywords)

# Convert to a DataFrame for easy handling
keyword_freq_df = pd.DataFrame(keyword_freq.items(), columns=['plot_keywords', 'frequency']).sort_values(by='frequency', ascending=False)

# Display the top 10 most frequent keywords
print(keyword_freq_df.head(10))
# Out:
#    plot_keywords  frequency
# 12         young       2034
# 52          life       1929
# 5            new       1544
# 11           man       1518
# 28        family       1280
# 36         world       1188
# 53         woman       1175
# 29          love        934
# 82         story        919
# 35         group        880

# %%
processing_df.drop(['Genres (full list)'], axis=1, inplace=True)
# Out:
# /var/folders/kl/36jj5f7x65x2wm9_48xpty780000gn/T/ipykernel_19385/3851438871.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   processing_df.drop(['Genres (full list)'], axis=1, inplace=True)

# %%
processing_df.head(20)
# Out:
#    Best Picture Certificate (GB) Certificate (US)  \
# 0          None               PG               PG
# 1          None               15                R
# 2          None               PG            PG-13
# 3          None             None            PG-13
# 4          None               15                R
# 5          None               12            PG-13
# 6          None               18                R
# 7          None               12            PG-13
# 8          None               15            PG-13
# 9          None               PG               PG
# 10         None             None            PG-13
# 11         None               15            TV-MA
# 12         None             None          Unrated
# 13         None               15                R
# 14         None               18                R
# 15         None               18        Not Rated
# 16         None               PG               PG
# 17         None               12          Unrated
# 18         None               15                R
# 19         None               18        Not Rated
#
#                                     Image Url (Title)  \
# 0   https://m.media-amazon.com/images/M/MV5BZjI0YT...
# 1   https://m.media-amazon.com/images/M/MV5BNGM1ND...
# 2   https://m.media-amazon.com/images/M/MV5BNzI4OT...
# 3   https://m.media-amazon.com/images/M/MV5BMjAzMT...
# 4   https://m.media-amazon.com/images/M/MV5BNDlmOT...
# 5   https://m.media-amazon.com/images/M/MV5BOTBjZj...
# 6   https://m.media-amazon.com/images/M/MV5BNDQ2MD...
# 7   https://m.media-amazon.com/images/M/MV5BYjc2Nz...
# 8   https://m.media-amazon.com/images/M/MV5BYWYzN2...
# 9   https://m.media-amazon.com/images/M/MV5BMDdhMW...
# 10  https://m.media-amazon.com/images/M/MV5BMTM2Zm...
# 11  https://m.media-amazon.com/images/M/MV5BMjM5Mz...
# 12  https://m.media-amazon.com/images/M/MV5BMDMxMz...
# 13  https://m.media-amazon.com/images/M/MV5BMzJlOW...
# 14  https://m.media-amazon.com/images/M/MV5BMTkxNz...
# 15  https://m.media-amazon.com/images/M/MV5BNWVmMz...
# 16  https://m.media-amazon.com/images/M/MV5BM2I1Mm...
# 17  https://m.media-amazon.com/images/M/MV5BMTU3Nz...
# 18  https://m.media-amazon.com/images/M/MV5BOWE0MG...
# 19  https://m.media-amazon.com/images/M/MV5BN2YyY2...
#
#                                                  Plot  \
# 0   The seniors return to Earth to visit their rel...
# 1   A sendup of all the teen movies that have accu...
# 2   A chef with a mysterious past spends the day w...
# 3   Two brothers and their surfing buddies face ne...
# 4   Sean Barker, unwilling host to an alien bio-ar...
# 5   A young man discovers a mechanical device that...
# 6   A prototype enhanced human, on the run from Ch...
# 7   A gubernatorial candidate hires a wormy specia...
# 8   A Japanese-American fisherman is accused of ki...
# 9   Two women, black and white, in 1955 Montgomery...
# 10  A multi-dimensional drama about a North Caroli...
# 11  A young programmer starts to question reality ...
# 12  A strip-joint owner and a manicurist find that...
# 13  Les is making a film about his old neighborhoo...
# 14  A group of college students on an overnite hay...
# 15  As the world is overrun by zombies, a group of...
# 16  To the world Ray Chase is nothing more than a ...
# 17  A troubled Native American veteran forms an ex...
# 18  A couple of creative losers accidently become ...
# 19  A psychotic killer convicted of multiple murde...
#
#                  Production Companies (1st)  \
# 0                  Zanuck/Brown Productions
# 1                         Columbia Pictures
# 2                            Metanoia Films
# 3                         Capstone Pictures
# 4                            Biomorphs Inc.
# 5                           New Line Cinema
# 6                        Overseas FilmGroup
# 7                         Broadway Pictures
# 8                        Universal Pictures
# 9                      Dave Bell Associates
# 10                  Addis Wechsler Pictures
# 11                        House Of Tomorrow
# 12                          Beyond Infinity
# 13                             Orenda Films
# 14                           H&G Films Ltd.
# 15  United Film Distribution Company (UFDC)
# 16                        Hit Entertainment
# 17                      Why Not Productions
# 18                              Front Films
# 19                     Albright/Platt Films
#
#                                         Title   Title Id  Year of Release  \
# 0                          Cocoon: The Return  tt0094890             1988
# 1                      Not Another Teen Movie  tt0277371             2001
# 2                                       Bella  tt0482463             2006
# 3                                  Local Boys  tt0293357             2002
# 4                           Guyver: Dark Hero  tt0109965             1994
# 5                                  The Guyver  tt0101988             1991
# 6                                       Drive  tt0116147             1997
# 7                                 Black Sheep  tt0115697             1996
# 8                      Snow Falling on Cedars  tt0120834             1999
# 9                          The Long Walk Home  tt0100046             1990
# 10                 The Journey of August King  tt0113490             1995
# 11                 Black Mirror: Bandersnatch  tt9495224             2018
# 12                            Psychos in Love  tt0093800             1987
# 13               The Search for One-eye Jimmy  tt0117577             1994
# 14                                 FleshEater  tt0109809             1988
# 15                            Day of the Dead  tt0088993             1985
# 16                      The Secret Agent Club  tt0117581             1996
# 17  Jimmy P: Psychotherapy of a Plains Indian  tt2210834             2013
# 18                                  Tapeheads  tt0096223             1988
# 19                            Luther the Geek  tt0100079             1989
#
#     IMDB Rating  Runtime (Minutes)  \
# 0           5.4              116.0
# 1           5.7               89.0
# 2           7.1               91.0
# 3           6.6              102.0
# 4           5.8              118.0
# 5           4.9               88.0
# 6           6.6              100.0
# 7           6.2               87.0
# 8           6.7              127.0
# 9           7.3               97.0
# 10          6.5               91.0
# 11          7.1               90.0
# 12          5.6               88.0
# 13          6.0               84.0
# 14          4.8               88.0
# 15          7.1              101.0
# 16          3.4               90.0
# 17          6.1              117.0
# 18          5.7               93.0
# 19          5.2               80.0
#
#                                           Lead Actors  \
# 0   ['Priscilla Ashley Behne', 'Bill Wohrman', 'Ba...
# 1   ['Lukas Behnken', 'Cody McMains', 'Deon Richmo...
# 2   ['Lukas Behnken', 'Dominic Colón', 'Hudson Coo...
# 3   ['Lukas Behnken', 'Travis Aaron Wade', 'Dick D...
# 4   ["'Evil' Ted Smith", 'Billi Lee', 'Brian Simps...
# 5   ["'Evil' Ted Smith", 'Brian Simpson', 'David W...
# 6   ["'Evil' Ted Smith", 'Kenny Richards', 'Dieter...
# 7   ["'Gypsy' Spheeris", 'Bruce McGill', 'Andrew B...
# 8   ['A. Arthur Takemoto', 'Max Wright', 'Daniel v...
# 9   ['A. Bernard Sneed', 'Charles Hubbard', 'Bobby...
# 10  ['A. Duncan Shirley III', 'George Lynch', 'Bil...
# 11  ['A.J. Houghton', 'Craig Parkinson', 'Alice Lo...
# 12  ["'Big' Marty", 'Barry Clark', 'Carmine Capobi...
# 13  ["'Stretch' Merced", 'Michael Louis Wells', 'A...
# 14  ["'Wild Bill' Laczko", 'Lutz Bacher', 'Bill In...
# 15  ["'Wild Bill' Laczko", 'Gary Howard Klar', 'Br...
# 16  ["'Wild' Bill Mock", 'Maurice Woods', 'Alex Ko...
# 17  ['A Martinez', 'Dennis North', 'Barton Bund', ...
# 18  ["'Agent' Ava Hubbard", "'Weird Al' Yankovic",...
# 19  ["'Chicken' Klabunde", 'Martin Widener', 'Davi...
#
#                                            genres  \
# 0   [Adventure, Comedy, Mystery, Romance, Sci-Fi]
# 1                                        [Comedy]
# 2                                [Drama, Romance]
# 3                                         [Drama]
# 4              [Action, Horror, Sci-Fi, Thriller]
# 5      [Action, Comedy, Horror, Sci-Fi, Thriller]
# 6             [Action, Adventure, Sci-Fi, Comedy]
# 7                                        [Comedy]
# 8             [Drama, Mystery, Romance, Thriller]
# 9                                [Drama, History]
# 10                                        [Drama]
# 11    [Drama, Fantasy, Mystery, Sci-Fi, Thriller]
# 12                               [Comedy, Horror]
# 13                                       [Comedy]
# 14                                       [Horror]
# 15                             [Horror, Thriller]
# 16                       [Action, Comedy, Family]
# 17                   [Biography, Drama, Thriller]
# 18                                [Comedy, Music]
# 19                               [Comedy, Horror]
#
#                                         plot_keywords
# 0                                               [old]
# 1                                              [past]
# 2                     [friend, day, mysterious, past]
# 3                                               [new]
# 4                                   [discover, fight]
# 5             [secret, begins, discovers, man, young]
# 6                                    [time, men, run]
# 7                                [brother, make, job]
# 8                                          [american]
# 9                                             [women]
# 10  [turns, help, comes, journey, year, home, way,...
# 11                                            [young]
# 12                                [family, love, day]
# 13                          [people, goes, film, old]
# 14                     [lives, college, group, fight]
# 15                                     [world, group]
# 16  [friends, high, returns, agent, son, years, wi...
# 17                                         [american]
# 18                                           [couple]
# 19               [takes, prison, killer, years, goes]

# %%
# from sklearn.preprocessing import LabelEncoder
# import pandas as pd

training_df = processing_df.copy()

# # extract all unique genres
# all_genres = set(genre for sublist in training_df['genres'] for genre in sublist)
# print(len(all_genres))
# le_genres = LabelEncoder()
# le_genres.fit(list(all_genres))
# training_df['genres_encoded'] = training_df['genres'].apply(le_genres.transform)


# all_production_companies = set(company for company in training_df['Production Companies (1st)'])
# print(len(all_production_companies))
# le_companies = LabelEncoder()
# le_companies.fit(list(all_production_companies))
# training_df['production_company_encoded'] = le_companies.transform(training_df['Production Companies (1st)'])



# all_plot_keywords = set(genre for sublist in training_df['plot_keywords'] for genre in sublist)
# print(len(all_plot_keywords))
# le_plot_keywords = LabelEncoder()
# le_plot_keywords.fit(list(all_plot_keywords))
# training_df['plot_keywords_encoded'] = training_df['plot_keywords'].apply(le_plot_keywords.transform)

# training_df['genres_decoded'] = training_df['genres_encoded'].apply(le_genres.inverse_transform)
# training_df['production_company_decoded'] = le_companies.inverse_transform(training_df['production_company_encoded'])
# training_df['plot_keywords_decode'] = training_df['plot_keywords_encoded'].apply(le_plot_keywords.inverse_transform)



# training_df.drop(['genres', 'production_companies', 'plot_keywords'], axis=1, inplace=True)

training_df.head(20)
# Out:
#    Best Picture Certificate (GB) Certificate (US)  \
# 0          None               PG               PG
# 1          None               15                R
# 2          None               PG            PG-13
# 3          None             None            PG-13
# 4          None               15                R
# 5          None               12            PG-13
# 6          None               18                R
# 7          None               12            PG-13
# 8          None               15            PG-13
# 9          None               PG               PG
# 10         None             None            PG-13
# 11         None               15            TV-MA
# 12         None             None          Unrated
# 13         None               15                R
# 14         None               18                R
# 15         None               18        Not Rated
# 16         None               PG               PG
# 17         None               12          Unrated
# 18         None               15                R
# 19         None               18        Not Rated
#
#                                     Image Url (Title)  \
# 0   https://m.media-amazon.com/images/M/MV5BZjI0YT...
# 1   https://m.media-amazon.com/images/M/MV5BNGM1ND...
# 2   https://m.media-amazon.com/images/M/MV5BNzI4OT...
# 3   https://m.media-amazon.com/images/M/MV5BMjAzMT...
# 4   https://m.media-amazon.com/images/M/MV5BNDlmOT...
# 5   https://m.media-amazon.com/images/M/MV5BOTBjZj...
# 6   https://m.media-amazon.com/images/M/MV5BNDQ2MD...
# 7   https://m.media-amazon.com/images/M/MV5BYjc2Nz...
# 8   https://m.media-amazon.com/images/M/MV5BYWYzN2...
# 9   https://m.media-amazon.com/images/M/MV5BMDdhMW...
# 10  https://m.media-amazon.com/images/M/MV5BMTM2Zm...
# 11  https://m.media-amazon.com/images/M/MV5BMjM5Mz...
# 12  https://m.media-amazon.com/images/M/MV5BMDMxMz...
# 13  https://m.media-amazon.com/images/M/MV5BMzJlOW...
# 14  https://m.media-amazon.com/images/M/MV5BMTkxNz...
# 15  https://m.media-amazon.com/images/M/MV5BNWVmMz...
# 16  https://m.media-amazon.com/images/M/MV5BM2I1Mm...
# 17  https://m.media-amazon.com/images/M/MV5BMTU3Nz...
# 18  https://m.media-amazon.com/images/M/MV5BOWE0MG...
# 19  https://m.media-amazon.com/images/M/MV5BN2YyY2...
#
#                                                  Plot  \
# 0   The seniors return to Earth to visit their rel...
# 1   A sendup of all the teen movies that have accu...
# 2   A chef with a mysterious past spends the day w...
# 3   Two brothers and their surfing buddies face ne...
# 4   Sean Barker, unwilling host to an alien bio-ar...
# 5   A young man discovers a mechanical device that...
# 6   A prototype enhanced human, on the run from Ch...
# 7   A gubernatorial candidate hires a wormy specia...
# 8   A Japanese-American fisherman is accused of ki...
# 9   Two women, black and white, in 1955 Montgomery...
# 10  A multi-dimensional drama about a North Caroli...
# 11  A young programmer starts to question reality ...
# 12  A strip-joint owner and a manicurist find that...
# 13  Les is making a film about his old neighborhoo...
# 14  A group of college students on an overnite hay...
# 15  As the world is overrun by zombies, a group of...
# 16  To the world Ray Chase is nothing more than a ...
# 17  A troubled Native American veteran forms an ex...
# 18  A couple of creative losers accidently become ...
# 19  A psychotic killer convicted of multiple murde...
#
#                  Production Companies (1st)  \
# 0                  Zanuck/Brown Productions
# 1                         Columbia Pictures
# 2                            Metanoia Films
# 3                         Capstone Pictures
# 4                            Biomorphs Inc.
# 5                           New Line Cinema
# 6                        Overseas FilmGroup
# 7                         Broadway Pictures
# 8                        Universal Pictures
# 9                      Dave Bell Associates
# 10                  Addis Wechsler Pictures
# 11                        House Of Tomorrow
# 12                          Beyond Infinity
# 13                             Orenda Films
# 14                           H&G Films Ltd.
# 15  United Film Distribution Company (UFDC)
# 16                        Hit Entertainment
# 17                      Why Not Productions
# 18                              Front Films
# 19                     Albright/Platt Films
#
#                                         Title   Title Id  Year of Release  \
# 0                          Cocoon: The Return  tt0094890             1988
# 1                      Not Another Teen Movie  tt0277371             2001
# 2                                       Bella  tt0482463             2006
# 3                                  Local Boys  tt0293357             2002
# 4                           Guyver: Dark Hero  tt0109965             1994
# 5                                  The Guyver  tt0101988             1991
# 6                                       Drive  tt0116147             1997
# 7                                 Black Sheep  tt0115697             1996
# 8                      Snow Falling on Cedars  tt0120834             1999
# 9                          The Long Walk Home  tt0100046             1990
# 10                 The Journey of August King  tt0113490             1995
# 11                 Black Mirror: Bandersnatch  tt9495224             2018
# 12                            Psychos in Love  tt0093800             1987
# 13               The Search for One-eye Jimmy  tt0117577             1994
# 14                                 FleshEater  tt0109809             1988
# 15                            Day of the Dead  tt0088993             1985
# 16                      The Secret Agent Club  tt0117581             1996
# 17  Jimmy P: Psychotherapy of a Plains Indian  tt2210834             2013
# 18                                  Tapeheads  tt0096223             1988
# 19                            Luther the Geek  tt0100079             1989
#
#     IMDB Rating  Runtime (Minutes)  \
# 0           5.4              116.0
# 1           5.7               89.0
# 2           7.1               91.0
# 3           6.6              102.0
# 4           5.8              118.0
# 5           4.9               88.0
# 6           6.6              100.0
# 7           6.2               87.0
# 8           6.7              127.0
# 9           7.3               97.0
# 10          6.5               91.0
# 11          7.1               90.0
# 12          5.6               88.0
# 13          6.0               84.0
# 14          4.8               88.0
# 15          7.1              101.0
# 16          3.4               90.0
# 17          6.1              117.0
# 18          5.7               93.0
# 19          5.2               80.0
#
#                                           Lead Actors  \
# 0   ['Priscilla Ashley Behne', 'Bill Wohrman', 'Ba...
# 1   ['Lukas Behnken', 'Cody McMains', 'Deon Richmo...
# 2   ['Lukas Behnken', 'Dominic Colón', 'Hudson Coo...
# 3   ['Lukas Behnken', 'Travis Aaron Wade', 'Dick D...
# 4   ["'Evil' Ted Smith", 'Billi Lee', 'Brian Simps...
# 5   ["'Evil' Ted Smith", 'Brian Simpson', 'David W...
# 6   ["'Evil' Ted Smith", 'Kenny Richards', 'Dieter...
# 7   ["'Gypsy' Spheeris", 'Bruce McGill', 'Andrew B...
# 8   ['A. Arthur Takemoto', 'Max Wright', 'Daniel v...
# 9   ['A. Bernard Sneed', 'Charles Hubbard', 'Bobby...
# 10  ['A. Duncan Shirley III', 'George Lynch', 'Bil...
# 11  ['A.J. Houghton', 'Craig Parkinson', 'Alice Lo...
# 12  ["'Big' Marty", 'Barry Clark', 'Carmine Capobi...
# 13  ["'Stretch' Merced", 'Michael Louis Wells', 'A...
# 14  ["'Wild Bill' Laczko", 'Lutz Bacher', 'Bill In...
# 15  ["'Wild Bill' Laczko", 'Gary Howard Klar', 'Br...
# 16  ["'Wild' Bill Mock", 'Maurice Woods', 'Alex Ko...
# 17  ['A Martinez', 'Dennis North', 'Barton Bund', ...
# 18  ["'Agent' Ava Hubbard", "'Weird Al' Yankovic",...
# 19  ["'Chicken' Klabunde", 'Martin Widener', 'Davi...
#
#                                            genres  \
# 0   [Adventure, Comedy, Mystery, Romance, Sci-Fi]
# 1                                        [Comedy]
# 2                                [Drama, Romance]
# 3                                         [Drama]
# 4              [Action, Horror, Sci-Fi, Thriller]
# 5      [Action, Comedy, Horror, Sci-Fi, Thriller]
# 6             [Action, Adventure, Sci-Fi, Comedy]
# 7                                        [Comedy]
# 8             [Drama, Mystery, Romance, Thriller]
# 9                                [Drama, History]
# 10                                        [Drama]
# 11    [Drama, Fantasy, Mystery, Sci-Fi, Thriller]
# 12                               [Comedy, Horror]
# 13                                       [Comedy]
# 14                                       [Horror]
# 15                             [Horror, Thriller]
# 16                       [Action, Comedy, Family]
# 17                   [Biography, Drama, Thriller]
# 18                                [Comedy, Music]
# 19                               [Comedy, Horror]
#
#                                         plot_keywords
# 0                                               [old]
# 1                                              [past]
# 2                     [friend, day, mysterious, past]
# 3                                               [new]
# 4                                   [discover, fight]
# 5             [secret, begins, discovers, man, young]
# 6                                    [time, men, run]
# 7                                [brother, make, job]
# 8                                          [american]
# 9                                             [women]
# 10  [turns, help, comes, journey, year, home, way,...
# 11                                            [young]
# 12                                [family, love, day]
# 13                          [people, goes, film, old]
# 14                     [lives, college, group, fight]
# 15                                     [world, group]
# 16  [friends, high, returns, agent, son, years, wi...
# 17                                         [american]
# 18                                           [couple]
# 19               [takes, prison, killer, years, goes]

# %%
training_df.to_csv('../data/training_df.csv', index=False)

# %%
# training_df.sort_values(by='Best Picture', ascending=False).head(5)
